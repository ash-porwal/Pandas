# %%
import pandas as pd

# %%
df = pd.read_csv("/home/ashporwal/hdd/lab/programmes/Python/Pandas/1_Series/TopRichestInWorld.csv")

# %%
df.head()
# Out:
#                        Name          NetWorth  Age Country/Territory  \
# 0                 Elon Musk  $219,000,000,000   50     United States
# 1                Jeff Bezos  $171,000,000,000   58     United States
# 2  Bernard Arnault & family  $158,000,000,000   73            France
# 3                Bill Gates  $129,000,000,000   66     United States
# 4            Warren Buffett  $118,000,000,000   91     United States
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
# Now I want to use Name as Index column and I will drop column Source
df = pd.read_csv("/home/ashporwal/hdd/lab/programmes/Python/Pandas/1_Series/TopRichestInWorld.csv", index_col='Name')
df.drop(columns=['Source'], inplace=True)
df.head()
# Out:
#                                   NetWorth  Age Country/Territory  \
# Name
# Elon Musk                 $219,000,000,000   50     United States
# Jeff Bezos                $171,000,000,000   58     United States
# Bernard Arnault & family  $158,000,000,000   73            France
# Bill Gates                $129,000,000,000   66     United States
# Warren Buffett            $118,000,000,000   91     United States
#
#                                        Industry
# Name
# Elon Musk                            Automotive
# Jeff Bezos                           Technology
# Bernard Arnault & family       Fashion & Retail
# Bill Gates                           Technology
# Warren Buffett            Finance & Investments

# %% [markdown]
# `Stacking` a dataset means - when we use `stack()` on a dataframe then it
# stacks all the column names and uses them as inner most index.
#
# The `stack()` function in Pandas is used to **pivot** or **"stack"** the columns of a DataFrame into a multi-level index (also called a hierarchical index). **It compresses the columns of a DataFrame into the rows**.
#
#
# Syntax:  `df.stack(level=-1, dropna=True)`
# - `level`: Specifies the level(s) to stack. By default, it stacks the innermost level.
# - `dropna`: If True, any rows with missing values after stacking are dropped. If False, they are kept.

# %%
# Example of stacking it:

mydata = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}

temp_df = pd.DataFrame(mydata)

temp_df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
stacked_df = temp_df.stack()

stacked_df
# Out:
# 0  A    1
#    B    4
#    C    7
# 1  A    2
#    B    5
#    C    8
# 2  A    3
#    B    6
#    C    9
# dtype: int64

# %% [markdown]
# **Explanation of Output**
# - The original columns become the second level of the index.
# - The values under each original column are now stacked vertically under a single column.
# - This is especially useful when you need to reshape data for specific types of analysis or visualization.
#
#
# **Use Cases**
# - Data Reshaping: Converting data from a wide format to a long format, which can be useful for certain types of data analysis or visualization.
# - Time Series Analysis: Useful in converting cross-sectional time-series data into a form that is easier to work with.
# - Data Cleaning: Helps in data normalization by transforming data into a tidy format where each variable is a column and each observation is a row.

# %%
# Accessing Inner Level index - 

# Accessing all data for index 0
stacked_df.loc[0]
# Out:
# A    1
# B    4
# C    7
# dtype: int64

# %%
# Accessing data for index 0 and column 'B'
stacked_df.loc[(0, 'B')]
# Out:
# np.int64(4)

# %%
df = df.stack(dropna=True) 
# as we overwrite it with stack, my all column names will be stacked under my index name,
# that is the reason I selected Name was index 
df
# Out:
# Name
# Elon Musk           NetWorth             $219,000,000,000
#                     Age                                50
#                     Country/Territory       United States
#                     Industry                   Automotive
# Jeff Bezos          NetWorth             $171,000,000,000
#                                                ...
# Luo Liguo & family  Industry                Manufacturing
# Peter Woo           NetWorth              $17,000,000,000
#                     Age                                75
#                     Country/Territory           Hong Kong
#                     Industry                  Real Estate
# Length: 404, dtype: object

# %%
# now we can again create a dataframe from above
pd.DataFrame(df)
# Out:
#                                                      0
# Name
# Elon Musk          NetWorth           $219,000,000,000
#                    Age                              50
#                    Country/Territory     United States
#                    Industry                 Automotive
# Jeff Bezos         NetWorth           $171,000,000,000
# ...                                                ...
# Luo Liguo & family Industry              Manufacturing
# Peter Woo          NetWorth            $17,000,000,000
#                    Age                              75
#                    Country/Territory         Hong Kong
#                    Industry                Real Estate
#
# [404 rows x 1 columns]

# %%
# Note our index now after Dataframe columns got stacked
df.index
# Out:
# MultiIndex([(               'Elon Musk',          'NetWorth'),
#             (               'Elon Musk',               'Age'),
#             (               'Elon Musk', 'Country/Territory'),
#             (               'Elon Musk',          'Industry'),
#             (              'Jeff Bezos',          'NetWorth'),
#             (              'Jeff Bezos',               'Age'),
#             (              'Jeff Bezos', 'Country/Territory'),
#             (              'Jeff Bezos',          'Industry'),
#             ('Bernard Arnault & family',          'NetWorth'),
#             ('Bernard Arnault & family',               'Age'),
#             ...
#             (            'Sun Piaoyang', 'Country/Territory'),
#             (            'Sun Piaoyang',          'Industry'),
#             (      'Luo Liguo & family',          'NetWorth'),
#             (      'Luo Liguo & family',               'Age'),
#             (      'Luo Liguo & family', 'Country/Territory'),
#             (      'Luo Liguo & family',          'Industry'),
#             (               'Peter Woo',          'NetWorth'),
#             (               'Peter Woo',               'Age'),
#             (               'Peter Woo', 'Country/Territory'),
#             (               'Peter Woo',          'Industry')],
#            names=['Name', None], length=404)

# %% [markdown]
# `Unstacking` a dataset - we can revert the stacking on dataframe

# %%
df = df.unstack()
df
# Out:
#                                   NetWorth Age Country/Territory  \
# Name
# Elon Musk                 $219,000,000,000  50     United States
# Jeff Bezos                $171,000,000,000  58     United States
# Bernard Arnault & family  $158,000,000,000  73            France
# Bill Gates                $129,000,000,000  66     United States
# Warren Buffett            $118,000,000,000  91     United States
# ...                                    ...  ..               ...
# Vladimir Potanin           $17,300,000,000  61            Russia
# Harold Hamm & family       $17,200,000,000  76     United States
# Sun Piaoyang               $17,100,000,000  63             China
# Luo Liguo & family         $17,000,000,000  66             China
# Peter Woo                  $17,000,000,000  75         Hong Kong
#
#                                        Industry
# Name
# Elon Musk                            Automotive
# Jeff Bezos                           Technology
# Bernard Arnault & family       Fashion & Retail
# Bill Gates                           Technology
# Warren Buffett            Finance & Investments
# ...                                         ...
# Vladimir Potanin                Metals & Mining
# Harold Hamm & family                     Energy
# Sun Piaoyang                         Healthcare
# Luo Liguo & family                Manufacturing
# Peter Woo                           Real Estate
#
# [101 rows x 4 columns]

# %% [markdown]
# ### But what happens if we unstack a fresh dataframe which was never got stacked.

# %%
# lets read the same file again
df = pd.read_csv(
    "/home/ashporwal/hdd/lab/programmes/Python/Pandas/1_Series/TopRichestInWorld.csv", 
    index_col=['Industry', 'Name'])

df
# Out:
#                                                         NetWorth  Age  \
# Industry              Name
# Automotive            Elon Musk                 $219,000,000,000   50
# Technology            Jeff Bezos                $171,000,000,000   58
# Fashion & Retail      Bernard Arnault & family  $158,000,000,000   73
# Technology            Bill Gates                $129,000,000,000   66
# Finance & Investments Warren Buffett            $118,000,000,000   91
# ...                                                          ...  ...
# Metals & Mining       Vladimir Potanin           $17,300,000,000   61
# Energy                Harold Hamm & family       $17,200,000,000   76
# Healthcare            Sun Piaoyang               $17,100,000,000   63
# Manufacturing         Luo Liguo & family         $17,000,000,000   66
# Real Estate           Peter Woo                  $17,000,000,000   75
#
#                                                Country/Territory  \
# Industry              Name
# Automotive            Elon Musk                    United States
# Technology            Jeff Bezos                   United States
# Fashion & Retail      Bernard Arnault & family            France
# Technology            Bill Gates                   United States
# Finance & Investments Warren Buffett               United States
# ...                                                          ...
# Metals & Mining       Vladimir Potanin                    Russia
# Energy                Harold Hamm & family         United States
# Healthcare            Sun Piaoyang                         China
# Manufacturing         Luo Liguo & family                   China
# Real Estate           Peter Woo                        Hong Kong
#
#                                                             Source
# Industry              Name
# Automotive            Elon Musk                      Tesla, SpaceX
# Technology            Jeff Bezos                            Amazon
# Fashion & Retail      Bernard Arnault & family                LVMH
# Technology            Bill Gates                         Microsoft
# Finance & Investments Warren Buffett            Berkshire Hathaway
# ...                                                            ...
# Metals & Mining       Vladimir Potanin                      metals
# Energy                Harold Hamm & family               oil & gas
# Healthcare            Sun Piaoyang                 pharmaceuticals
# Manufacturing         Luo Liguo & family                 chemicals
# Real Estate           Peter Woo                        real estate
#
# [101 rows x 4 columns]

# %%
df.unstack()
# Out:
#                               NetWorth                                    \
# Name                   Abigail Johnson Alain Wertheimer     Alice Walton
# Industry
# Automotive                         NaN              NaN              NaN
# Diversified                        NaN              NaN              NaN
# Energy                             NaN              NaN              NaN
# Fashion & Retail                   NaN  $31,200,000,000  $65,300,000,000
# Finance & Investments  $21,200,000,000              NaN              NaN
# Food & Beverage                    NaN              NaN              NaN
# Gambling & Casinos                 NaN              NaN              NaN
# Healthcare                         NaN              NaN              NaN
# Logistics                          NaN              NaN              NaN
# Manufacturing                      NaN              NaN              NaN
# Media & Entertainment              NaN              NaN              NaN
# Metals & Mining                    NaN              NaN              NaN
# Real Estate                        NaN              NaN              NaN
# Service                            NaN              NaN              NaN
# Technology                         NaN              NaN              NaN
# Telecom                            NaN              NaN              NaN
#
#                                                          \
# Name                    Amancio Ortega   Andrew Forrest
# Industry
# Automotive                         NaN              NaN
# Diversified                        NaN              NaN
# Energy                             NaN              NaN
# Fashion & Retail       $59,600,000,000              NaN
# Finance & Investments              NaN              NaN
# Food & Beverage                    NaN              NaN
# Gambling & Casinos                 NaN              NaN
# Healthcare                         NaN              NaN
# Logistics                          NaN              NaN
# Manufacturing                      NaN              NaN
# Media & Entertainment              NaN              NaN
# Metals & Mining                    NaN  $17,800,000,000
# Real Estate                        NaN              NaN
# Service                            NaN              NaN
# Technology                         NaN              NaN
# Telecom                            NaN              NaN
#
#                                                                   \
# Name                  Beate Heister & Karl Albrecht Jr. & family
# Industry
# Automotive                                                   NaN
# Diversified                                                  NaN
# Energy                                                       NaN
# Fashion & Retail                                 $36,800,000,000
# Finance & Investments                                        NaN
# Food & Beverage                                              NaN
# Gambling & Casinos                                           NaN
# Healthcare                                                   NaN
# Logistics                                                    NaN
# Manufacturing                                                NaN
# Media & Entertainment                                        NaN
# Metals & Mining                                              NaN
# Real Estate                                                  NaN
# Service                                                      NaN
# Technology                                                   NaN
# Telecom                                                      NaN
#
#                                                                   \
# Name                  Bernard Arnault & family        Bill Gates
# Industry
# Automotive                                 NaN               NaN
# Diversified                                NaN               NaN
# Energy                                     NaN               NaN
# Fashion & Retail              $158,000,000,000               NaN
# Finance & Investments                      NaN               NaN
# Food & Beverage                            NaN               NaN
# Gambling & Casinos                         NaN               NaN
# Healthcare                                 NaN               NaN
# Logistics                                  NaN               NaN
# Manufacturing                              NaN               NaN
# Media & Entertainment                      NaN               NaN
# Metals & Mining                            NaN               NaN
# Real Estate                                NaN               NaN
# Service                                    NaN               NaN
# Technology                                 NaN  $129,000,000,000
# Telecom                                    NaN               NaN
#
#                                                                   ...  \
# Name                  Carlos Slim Helu & family   Changpeng Zhao  ...
# Industry                                                          ...
# Automotive                                  NaN              NaN  ...
# Diversified                                 NaN              NaN  ...
# Energy                                      NaN              NaN  ...
# Fashion & Retail                            NaN              NaN  ...
# Finance & Investments                       NaN  $65,000,000,000  ...
# Food & Beverage                             NaN              NaN  ...
# Gambling & Casinos                          NaN              NaN  ...
# Healthcare                                  NaN              NaN  ...
# Logistics                                   NaN              NaN  ...
# Manufacturing                               NaN              NaN  ...
# Media & Entertainment                       NaN              NaN  ...
# Metals & Mining                             NaN              NaN  ...
# Real Estate                                 NaN              NaN  ...
# Service                                     NaN              NaN  ...
# Technology                                  NaN              NaN  ...
# Telecom                         $81,200,000,000              NaN  ...
#
#                                  Source                   \
# Name                     Vladimir Lisin Vladimir Potanin
# Industry
# Automotive                          NaN              NaN
# Diversified                         NaN              NaN
# Energy                              NaN              NaN
# Fashion & Retail                    NaN              NaN
# Finance & Investments               NaN              NaN
# Food & Beverage                     NaN              NaN
# Gambling & Casinos                  NaN              NaN
# Healthcare                          NaN              NaN
# Logistics                           NaN              NaN
# Manufacturing                       NaN              NaN
# Media & Entertainment               NaN              NaN
# Metals & Mining        steel, transport           metals
# Real Estate                         NaN              NaN
# Service                             NaN              NaN
# Technology                          NaN              NaN
# Telecom                             NaN              NaN
#
#                                                                  \
# Name                             Wang Chuanfu          Wang Wei
# Industry
# Automotive             batteries, automobiles               NaN
# Diversified                               NaN               NaN
# Energy                                    NaN               NaN
# Fashion & Retail                          NaN               NaN
# Finance & Investments                     NaN               NaN
# Food & Beverage                           NaN               NaN
# Gambling & Casinos                        NaN               NaN
# Healthcare                                NaN               NaN
# Logistics                                 NaN               NaN
# Manufacturing                             NaN               NaN
# Media & Entertainment                     NaN               NaN
# Metals & Mining                           NaN               NaN
# Real Estate                               NaN               NaN
# Service                                   NaN  package delivery
# Technology                                NaN               NaN
# Telecom                                   NaN               NaN
#
#                                                                     \
# Name                               Wang Wenyin      Warren Buffett
# Industry
# Automotive                                 NaN                 NaN
# Diversified                                NaN                 NaN
# Energy                                     NaN                 NaN
# Fashion & Retail                           NaN                 NaN
# Finance & Investments                      NaN  Berkshire Hathaway
# Food & Beverage                            NaN                 NaN
# Gambling & Casinos                         NaN                 NaN
# Healthcare                                 NaN                 NaN
# Logistics                                  NaN                 NaN
# Manufacturing                              NaN                 NaN
# Media & Entertainment                      NaN                 NaN
# Metals & Mining        mining, copper products                 NaN
# Real Estate                                NaN                 NaN
# Service                                    NaN                 NaN
# Technology                                 NaN                 NaN
# Telecom                                    NaN                 NaN
#
#                                                                           \
# Name                  William Lei Ding Yang Huiyan & family Zhang Yiming
# Industry
# Automotive                         NaN                  NaN          NaN
# Diversified                        NaN                  NaN          NaN
# Energy                             NaN                  NaN          NaN
# Fashion & Retail                   NaN                  NaN          NaN
# Finance & Investments              NaN                  NaN          NaN
# Food & Beverage                    NaN                  NaN          NaN
# Gambling & Casinos                 NaN                  NaN          NaN
# Healthcare                         NaN                  NaN          NaN
# Logistics                          NaN                  NaN          NaN
# Manufacturing                      NaN                  NaN          NaN
# Media & Entertainment              NaN                  NaN       TikTok
# Metals & Mining                    NaN                  NaN          NaN
# Real Estate                        NaN          real estate          NaN
# Service                            NaN                  NaN          NaN
# Technology                online games                  NaN          NaN
# Telecom                            NaN                  NaN          NaN
#
#
# Name                               Zhong Shanshan
# Industry
# Automotive                                    NaN
# Diversified                                   NaN
# Energy                                        NaN
# Fashion & Retail                              NaN
# Finance & Investments                         NaN
# Food & Beverage        beverages, pharmaceuticals
# Gambling & Casinos                            NaN
# Healthcare                                    NaN
# Logistics                                     NaN
# Manufacturing                                 NaN
# Media & Entertainment                         NaN
# Metals & Mining                               NaN
# Real Estate                                   NaN
# Service                                       NaN
# Technology                                    NaN
# Telecom                                       NaN
#
# [16 rows x 404 columns]

# %%
# but we can also specify to which level of index we want to unstack
df.unstack(level=0)  
# in this all Industry column will be in horizontal postion as compated to above
# Out:
#                        NetWorth                                      \
# Industry             Automotive Diversified Energy Fashion & Retail
# Name
# Abigail Johnson             NaN         NaN    NaN              NaN
# Alain Wertheimer            NaN         NaN    NaN  $31,200,000,000
# Alice Walton                NaN         NaN    NaN  $65,300,000,000
# Amancio Ortega              NaN         NaN    NaN  $59,600,000,000
# Andrew Forrest              NaN         NaN    NaN              NaN
# ...                         ...         ...    ...              ...
# Warren Buffett              NaN         NaN    NaN              NaN
# William Lei Ding            NaN         NaN    NaN              NaN
# Yang Huiyan & family        NaN         NaN    NaN              NaN
# Zhang Yiming                NaN         NaN    NaN              NaN
# Zhong Shanshan              NaN         NaN    NaN              NaN
#
#                                                              \
# Industry             Finance & Investments  Food & Beverage
# Name
# Abigail Johnson            $21,200,000,000              NaN
# Alain Wertheimer                       NaN              NaN
# Alice Walton                           NaN              NaN
# Amancio Ortega                         NaN              NaN
# Andrew Forrest                         NaN              NaN
# ...                                    ...              ...
# Warren Buffett            $118,000,000,000              NaN
# William Lei Ding                       NaN              NaN
# Yang Huiyan & family                   NaN              NaN
# Zhang Yiming                           NaN              NaN
# Zhong Shanshan                         NaN  $65,700,000,000
#
#                                                                             \
# Industry             Gambling & Casinos Healthcare Logistics Manufacturing
# Name
# Abigail Johnson                     NaN        NaN       NaN           NaN
# Alain Wertheimer                    NaN        NaN       NaN           NaN
# Alice Walton                        NaN        NaN       NaN           NaN
# Amancio Ortega                      NaN        NaN       NaN           NaN
# Andrew Forrest                      NaN        NaN       NaN           NaN
# ...                                 ...        ...       ...           ...
# Warren Buffett                      NaN        NaN       NaN           NaN
# William Lei Ding                    NaN        NaN       NaN           NaN
# Yang Huiyan & family                NaN        NaN       NaN           NaN
# Zhang Yiming                        NaN        NaN       NaN           NaN
# Zhong Shanshan                      NaN        NaN       NaN           NaN
#
#                       ...             Source                       \
# Industry              ... Gambling & Casinos Healthcare Logistics
# Name                  ...
# Abigail Johnson       ...                NaN        NaN       NaN
# Alain Wertheimer      ...                NaN        NaN       NaN
# Alice Walton          ...                NaN        NaN       NaN
# Amancio Ortega        ...                NaN        NaN       NaN
# Andrew Forrest        ...                NaN        NaN       NaN
# ...                   ...                ...        ...       ...
# Warren Buffett        ...                NaN        NaN       NaN
# William Lei Ding      ...                NaN        NaN       NaN
# Yang Huiyan & family  ...                NaN        NaN       NaN
# Zhang Yiming          ...                NaN        NaN       NaN
# Zhong Shanshan        ...                NaN        NaN       NaN
#
#                                                                           \
# Industry             Manufacturing Media & Entertainment Metals & Mining
# Name
# Abigail Johnson                NaN                   NaN             NaN
# Alain Wertheimer               NaN                   NaN             NaN
# Alice Walton                   NaN                   NaN             NaN
# Amancio Ortega                 NaN                   NaN             NaN
# Andrew Forrest                 NaN                   NaN          mining
# ...                            ...                   ...             ...
# Warren Buffett                 NaN                   NaN             NaN
# William Lei Ding               NaN                   NaN             NaN
# Yang Huiyan & family           NaN                   NaN             NaN
# Zhang Yiming                   NaN                TikTok             NaN
# Zhong Shanshan                 NaN                   NaN             NaN
#
#
# Industry              Real Estate Service    Technology Telecom
# Name
# Abigail Johnson               NaN     NaN           NaN     NaN
# Alain Wertheimer              NaN     NaN           NaN     NaN
# Alice Walton                  NaN     NaN           NaN     NaN
# Amancio Ortega                NaN     NaN           NaN     NaN
# Andrew Forrest                NaN     NaN           NaN     NaN
# ...                           ...     ...           ...     ...
# Warren Buffett                NaN     NaN           NaN     NaN
# William Lei Ding              NaN     NaN  online games     NaN
# Yang Huiyan & family  real estate     NaN           NaN     NaN
# Zhang Yiming                  NaN     NaN           NaN     NaN
# Zhong Shanshan                NaN     NaN           NaN     NaN
#
# [101 rows x 64 columns]

# %%
df.unstack(level=1)
# Out:
#                               NetWorth                                    \
# Name                   Abigail Johnson Alain Wertheimer     Alice Walton
# Industry
# Automotive                         NaN              NaN              NaN
# Diversified                        NaN              NaN              NaN
# Energy                             NaN              NaN              NaN
# Fashion & Retail                   NaN  $31,200,000,000  $65,300,000,000
# Finance & Investments  $21,200,000,000              NaN              NaN
# Food & Beverage                    NaN              NaN              NaN
# Gambling & Casinos                 NaN              NaN              NaN
# Healthcare                         NaN              NaN              NaN
# Logistics                          NaN              NaN              NaN
# Manufacturing                      NaN              NaN              NaN
# Media & Entertainment              NaN              NaN              NaN
# Metals & Mining                    NaN              NaN              NaN
# Real Estate                        NaN              NaN              NaN
# Service                            NaN              NaN              NaN
# Technology                         NaN              NaN              NaN
# Telecom                            NaN              NaN              NaN
#
#                                                          \
# Name                    Amancio Ortega   Andrew Forrest
# Industry
# Automotive                         NaN              NaN
# Diversified                        NaN              NaN
# Energy                             NaN              NaN
# Fashion & Retail       $59,600,000,000              NaN
# Finance & Investments              NaN              NaN
# Food & Beverage                    NaN              NaN
# Gambling & Casinos                 NaN              NaN
# Healthcare                         NaN              NaN
# Logistics                          NaN              NaN
# Manufacturing                      NaN              NaN
# Media & Entertainment              NaN              NaN
# Metals & Mining                    NaN  $17,800,000,000
# Real Estate                        NaN              NaN
# Service                            NaN              NaN
# Technology                         NaN              NaN
# Telecom                            NaN              NaN
#
#                                                                   \
# Name                  Beate Heister & Karl Albrecht Jr. & family
# Industry
# Automotive                                                   NaN
# Diversified                                                  NaN
# Energy                                                       NaN
# Fashion & Retail                                 $36,800,000,000
# Finance & Investments                                        NaN
# Food & Beverage                                              NaN
# Gambling & Casinos                                           NaN
# Healthcare                                                   NaN
# Logistics                                                    NaN
# Manufacturing                                                NaN
# Media & Entertainment                                        NaN
# Metals & Mining                                              NaN
# Real Estate                                                  NaN
# Service                                                      NaN
# Technology                                                   NaN
# Telecom                                                      NaN
#
#                                                                   \
# Name                  Bernard Arnault & family        Bill Gates
# Industry
# Automotive                                 NaN               NaN
# Diversified                                NaN               NaN
# Energy                                     NaN               NaN
# Fashion & Retail              $158,000,000,000               NaN
# Finance & Investments                      NaN               NaN
# Food & Beverage                            NaN               NaN
# Gambling & Casinos                         NaN               NaN
# Healthcare                                 NaN               NaN
# Logistics                                  NaN               NaN
# Manufacturing                              NaN               NaN
# Media & Entertainment                      NaN               NaN
# Metals & Mining                            NaN               NaN
# Real Estate                                NaN               NaN
# Service                                    NaN               NaN
# Technology                                 NaN  $129,000,000,000
# Telecom                                    NaN               NaN
#
#                                                                   ...  \
# Name                  Carlos Slim Helu & family   Changpeng Zhao  ...
# Industry                                                          ...
# Automotive                                  NaN              NaN  ...
# Diversified                                 NaN              NaN  ...
# Energy                                      NaN              NaN  ...
# Fashion & Retail                            NaN              NaN  ...
# Finance & Investments                       NaN  $65,000,000,000  ...
# Food & Beverage                             NaN              NaN  ...
# Gambling & Casinos                          NaN              NaN  ...
# Healthcare                                  NaN              NaN  ...
# Logistics                                   NaN              NaN  ...
# Manufacturing                               NaN              NaN  ...
# Media & Entertainment                       NaN              NaN  ...
# Metals & Mining                             NaN              NaN  ...
# Real Estate                                 NaN              NaN  ...
# Service                                     NaN              NaN  ...
# Technology                                  NaN              NaN  ...
# Telecom                         $81,200,000,000              NaN  ...
#
#                                  Source                   \
# Name                     Vladimir Lisin Vladimir Potanin
# Industry
# Automotive                          NaN              NaN
# Diversified                         NaN              NaN
# Energy                              NaN              NaN
# Fashion & Retail                    NaN              NaN
# Finance & Investments               NaN              NaN
# Food & Beverage                     NaN              NaN
# Gambling & Casinos                  NaN              NaN
# Healthcare                          NaN              NaN
# Logistics                           NaN              NaN
# Manufacturing                       NaN              NaN
# Media & Entertainment               NaN              NaN
# Metals & Mining        steel, transport           metals
# Real Estate                         NaN              NaN
# Service                             NaN              NaN
# Technology                          NaN              NaN
# Telecom                             NaN              NaN
#
#                                                                  \
# Name                             Wang Chuanfu          Wang Wei
# Industry
# Automotive             batteries, automobiles               NaN
# Diversified                               NaN               NaN
# Energy                                    NaN               NaN
# Fashion & Retail                          NaN               NaN
# Finance & Investments                     NaN               NaN
# Food & Beverage                           NaN               NaN
# Gambling & Casinos                        NaN               NaN
# Healthcare                                NaN               NaN
# Logistics                                 NaN               NaN
# Manufacturing                             NaN               NaN
# Media & Entertainment                     NaN               NaN
# Metals & Mining                           NaN               NaN
# Real Estate                               NaN               NaN
# Service                                   NaN  package delivery
# Technology                                NaN               NaN
# Telecom                                   NaN               NaN
#
#                                                                     \
# Name                               Wang Wenyin      Warren Buffett
# Industry
# Automotive                                 NaN                 NaN
# Diversified                                NaN                 NaN
# Energy                                     NaN                 NaN
# Fashion & Retail                           NaN                 NaN
# Finance & Investments                      NaN  Berkshire Hathaway
# Food & Beverage                            NaN                 NaN
# Gambling & Casinos                         NaN                 NaN
# Healthcare                                 NaN                 NaN
# Logistics                                  NaN                 NaN
# Manufacturing                              NaN                 NaN
# Media & Entertainment                      NaN                 NaN
# Metals & Mining        mining, copper products                 NaN
# Real Estate                                NaN                 NaN
# Service                                    NaN                 NaN
# Technology                                 NaN                 NaN
# Telecom                                    NaN                 NaN
#
#                                                                           \
# Name                  William Lei Ding Yang Huiyan & family Zhang Yiming
# Industry
# Automotive                         NaN                  NaN          NaN
# Diversified                        NaN                  NaN          NaN
# Energy                             NaN                  NaN          NaN
# Fashion & Retail                   NaN                  NaN          NaN
# Finance & Investments              NaN                  NaN          NaN
# Food & Beverage                    NaN                  NaN          NaN
# Gambling & Casinos                 NaN                  NaN          NaN
# Healthcare                         NaN                  NaN          NaN
# Logistics                          NaN                  NaN          NaN
# Manufacturing                      NaN                  NaN          NaN
# Media & Entertainment              NaN                  NaN       TikTok
# Metals & Mining                    NaN                  NaN          NaN
# Real Estate                        NaN          real estate          NaN
# Service                            NaN                  NaN          NaN
# Technology                online games                  NaN          NaN
# Telecom                            NaN                  NaN          NaN
#
#
# Name                               Zhong Shanshan
# Industry
# Automotive                                    NaN
# Diversified                                   NaN
# Energy                                        NaN
# Fashion & Retail                              NaN
# Finance & Investments                         NaN
# Food & Beverage        beverages, pharmaceuticals
# Gambling & Casinos                            NaN
# Healthcare                                    NaN
# Logistics                                     NaN
# Manufacturing                                 NaN
# Media & Entertainment                         NaN
# Metals & Mining                               NaN
# Real Estate                                   NaN
# Service                                       NaN
# Technology                                    NaN
# Telecom                                       NaN
#
# [16 rows x 404 columns]
