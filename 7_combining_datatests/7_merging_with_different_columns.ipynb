# %%
import pandas as pd

# %%
cols = ["Name", "Salary"]
company21 = pd.read_csv(
    "company21.csv", 
    sep=';',
    usecols=cols
    )
company22 = pd.read_csv(
    "company22.csv", 
    sep=';',
    usecols=cols
    )

# %%
company22.rename(columns={'Name': 'Employee'}, inplace=True)
company22
# Out:
#     Employee  Salary
# 0      Ethan   30000
# 1     Olivia   25000
# 2       Liam   40000
# 3     Robert   20000
# 4   Benjamin   10000
# 5      Maria  150000
# 6   Federico  150000
# 7      James   50000
# 8   Isabella   40000
# 9       Mark  120000
# 10   Philipp   60000

# %% [markdown]
# Now, we have different column names in both df, so if we merge it then we will get keyerror

# %%
pd.merge(
    left=company21,
    right=company22,
    how='outer',
    on='Name',
    suffixes=('_21', '_22'),
    indicator=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6819/3525834909.py in ?()
# ----> 1 pd.merge(
#       2     left=company21,
#       3     right=company22,
#       4     how='outer',
#
# ~/.local/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# ~/.local/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
# ...

# %% [markdown]
# Now, we know that from left df column name `Name` is same as `Employee` from right df
#
# So, we can specify this `left_on` keyword and `right_on` keyword instead of `on`, and it will try to merge both of these columns mentioned in `left_on` and `right_on`

# %%
pd.merge(
    left=company21,
    right=company22,
    how='outer',
    left_on='Name',
    right_on='Employee',
    suffixes=('_21', '_22'),
    indicator=True
)
# Out:
#          Name  Salary_21  Employee  Salary_22      _merge
# 0       Ethan    20000.0     Ethan    30000.0        both
# 1      Olivia    30000.0    Olivia    25000.0        both
# 2        Liam    40000.0      Liam    40000.0        both
# 3        Emma    20000.0       NaN        NaN   left_only
# 4    Benjamin    10000.0  Benjamin    10000.0        both
# 5         Ava   100000.0       NaN        NaN   left_only
# 6   Alexander    20000.0       NaN        NaN   left_only
# 7       James    40000.0     James    50000.0        both
# 8    Isabella    40000.0  Isabella    40000.0        both
# 9        Mark   120000.0      Mark   120000.0        both
# 10        NaN        NaN    Robert    20000.0  right_only
# 11        NaN        NaN     Maria   150000.0  right_only
# 12        NaN        NaN  Federico   150000.0  right_only
# 13        NaN        NaN   Philipp    60000.0  right_only
