# %%
import pandas as pd

# %%
rich_df = pd.read_csv("TopRichestInWorld.csv")
rich_df # This will return whole file
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
# If we just want tp see some rows
# lets say need to see starting 10rows
rich_df.head(10)
# Out:
#                        Name          NetWorth  Age Country/Territory  \
# 0                 Elon Musk  $219,000,000,000   50     United States
# 1                Jeff Bezos  $171,000,000,000   58     United States
# 2  Bernard Arnault & family  $158,000,000,000   73            France
# 3                Bill Gates  $129,000,000,000   66     United States
# 4            Warren Buffett  $118,000,000,000   91     United States
# 5                Larry Page  $111,000,000,000   49     United States
# 6               Sergey Brin  $107,000,000,000   48     United States
# 7             Larry Ellison  $106,000,000,000   77     United States
# 8             Steve Ballmer   $91,400,000,000   66     United States
# 9             Mukesh Ambani   $90,700,000,000   64             India
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# ...

# %%
# if we don't define any number insdie .head() then its default value is 5
rich_df.head()
# Out:
#                        Name          NetWorth  Age Country/Territory  \
# 0                 Elon Musk  $219,000,000,000   50     United States
# 1                Jeff Bezos  $171,000,000,000   58     United States
# 2  Bernard Arnault & family  $158,000,000,000   73            France
# 3                Bill Gates  $129,000,000,000   66     United States
# 4            Warren Buffett  $118,000,000,000   91     United States
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
# if we do something like this
rich_df.head(-20) # This will return all expect last 20 rows.
# Out:
#                         Name          NetWorth  Age Country/Territory  \
# 0                  Elon Musk  $219,000,000,000   50     United States
# 1                 Jeff Bezos  $171,000,000,000   58     United States
# 2   Bernard Arnault & family  $158,000,000,000   73            France
# 3                 Bill Gates  $129,000,000,000   66     United States
# 4             Warren Buffett  $118,000,000,000   91     United States
# ..                       ...               ...  ...               ...
# 76             Stefan Quandt   $20,700,000,000   55           Germany
# 77              Jensen Huang   $20,600,000,000   59     United States
# 78              Huang Shilin   $20,300,000,000   55             China
# 79           Thomas Peterffy   $20,100,000,000   77     United States
# 80        Radhakishan Damani   $20,000,000,000   67             India
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
# Similarly we have tail() to see rows from bottom
rich_df.tail()
# Out:
#                      Name         NetWorth  Age Country/Territory  \
# 96       Vladimir Potanin  $17,300,000,000   61            Russia
# 97   Harold Hamm & family  $17,200,000,000   76     United States
# 98           Sun Piaoyang  $17,100,000,000   63             China
# 99     Luo Liguo & family  $17,000,000,000   66             China
# 100             Peter Woo  $17,000,000,000   75         Hong Kong
#
#               Source         Industry
# 96            metals  Metals & Mining
# 97         oil & gas           Energy
# 98   pharmaceuticals       Healthcare
# 99         chemicals    Manufacturing
# 100      real estate      Real Estate

# %%
rich_df.tail(-10) # Will return all rows from starting to end (excluding the first 10 rows)
# Out:
#                                       Name         NetWorth  Age  \
# 10                   Gautam Adani & family  $90,000,000,000   59
# 11                       Michael Bloomberg  $82,000,000,000   80
# 12               Carlos Slim Helu & family  $81,200,000,000   82
# 13   Francoise Bettencourt Meyers & family  $74,800,000,000   68
# 14                         Mark Zuckerberg  $67,300,000,000   37
# ..                                     ...              ...  ...
# 96                        Vladimir Potanin  $17,300,000,000   61
# 97                    Harold Hamm & family  $17,200,000,000   76
# 98                            Sun Piaoyang  $17,100,000,000   63
# 99                      Luo Liguo & family  $17,000,000,000   66
# 100                              Peter Woo  $17,000,000,000   75
#
#     Country/Territory                       Source               Industry
# 10              India  infrastructure, commodities            Diversified
# ...

# %%
rich_df.to_string() # This will print all the Dataframe
# Out:
# "                                           Name          NetWorth  Age Country/Territory                       Source               Industry\n0                                     Elon Musk  $219,000,000,000   50     United States                Tesla, SpaceX             Automotive\n1                                    Jeff Bezos  $171,000,000,000   58     United States                       Amazon             Technology\n2                      Bernard Arnault & family  $158,000,000,000   73            France                         LVMH       Fashion & Retail\n3                                    Bill Gates  $129,000,000,000   66     United States                    Microsoft             Technology\n4                                Warren Buffett  $118,000,000,000   91     United States           Berkshire Hathaway  Finance & Investments\n5                                    Larry Page  $111,000,000,000   49     United States                       Google             Technology\n6  
# ...
