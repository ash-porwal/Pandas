# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cols = ['date', 'high', 'low', 'open', 'close']

apple_stocks = pd.read_csv("AAPL.csv", usecols=cols, index_col='date', parse_dates=['date'])
apple_stocks
# Out:
#                              close     high       low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86
# ...                            ...      ...       ...     ...
# 2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17
# 2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03
# 2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68
# 2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66
# 2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77
#
# [1258 rows x 4 columns]

# %% [markdown]
# Plot some specific values from dataframe

# %%
# we need to use .loc method
# as we already made date column as index, so lets see first how that dataframe looks like
apple_stocks.head()
# Out:
#                              close     high     low    open
# date
# 2015-05-27 00:00:00+00:00  132.045  132.260  130.05  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.950  131.10  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.450  129.90  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.390  130.05  131.20
# 2015-06-02 00:00:00+00:00  129.960  130.655  129.32  129.86

# %%
# so now we can select values using index
apple_stocks.loc['2016-05'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# now even above is data for 2016 but included all the columns.
# To select specific columns

# %%
apple_stocks.plot(
    y = 'close' # defining y-axis and this can be a list of columns or a single column
    )
# Out:
# <Axes: xlabel='date'>

# %%
apple_stocks.plot(
    y = ['close', 'open'] # defining y-axis and this can be a list of columns or a single column
    )
# Out:
# <Axes: xlabel='date'>

# %%
# want plot on 2016 year of data
apple_stocks.loc['2016-05'].plot(
    y = ['close', 'open'] # defining y-axis and this can be a list of columns or a single column
    )
# Out:
# <Axes: xlabel='date'>

# %%
# Getting one plot for each column
# for this we just need to set subplots to True

apple_stocks.plot(subplots=True)
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %%
# we can resize it as well with - figsize parameter
apple_stocks.plot(subplots=True, figsize=(20, 20)) # figsize takes dimensions in tuples
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %% [markdown]
# Modifying Plot informations like
# 1. Setting Title

# %%
apple_stocks.plot()
plt.title("Apple stocks")
# Out:
# Text(0.5, 1.0, 'Apple stocks')

# %%
# setting X label and Y label
apple_stocks.plot()
plt.title("Apple stocks")
plt.xlabel("Years")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
# getting grid in plot
apple_stocks.plot()
plt.title("Apple stocks")
plt.xlabel("Years")
plt.ylabel("Price")
plt.grid()

# %% [markdown]
# Above we noticed, column names are given in color -
# 1. Close - is in blue
# 2. high - is in orange
# 3. low - is in green
# 4. open - is in red
#
# but we can also change this color with `c` parameter

# %%
# want close column in green color and data should be picked from 2016
apple_stocks.loc['2016-05'].plot(
    y='close',
    c='g'
)
# Out:
# <Axes: xlabel='date'>

# %%
# we can increase the width of the line as well
apple_stocks.loc['2016-05'].plot(
    y='close',
    c='g',
    linewidth=5
)
# Out:
# <Axes: xlabel='date'>

# %%
# we can change the style of line as well
apple_stocks.loc['2016-05'].plot(
    y='close',
    c='g',
    linewidth=5,
    linestyle=":" # want in dotted
)
# Out:
# <Axes: xlabel='date'>
