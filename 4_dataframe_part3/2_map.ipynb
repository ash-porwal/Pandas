# %%
import pandas as pd

# %%
df = pd.read_csv("Pokemon.csv", index_col='#')
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### map()
# The map() function in Pandas is used primarily with Series objects to substitute each value in a Series with another value.
#
# *Syntax:*
#     `Series.map(arg, na_action=None)`
#
#
# **Parameters:**
#
# - **arg:** Can be a function, dictionary, or Series that defines the mapping correspondence.
#     1. Function: A function to apply to each value in the Series.
#     2. Dictionary: A dictionary where keys are the old values and values are the new values.
#     3. Series: Another Series to map values based on the index.
# - **na_action:** Can be None (default) or 'ignore'. If 'ignore', NaN values are propagated without being passed to the arg function.

# %%
# I am converting all False value to No and True to Yes in the Legendary column.
df['Legendary'] = df['Legendary'].map({False: 'No', True: 'Yes'})
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation Legendary
# #
# 1       65     45           1        No
# 2       80     60           1        No
# 3      100     80           1        No
# 3      120     80           1        No
# 4       50     65           1        No

# %%
# if we selected that column whose values we want to map
# if we don't specify all the values in the column then the values which are not
# specified will be converted to NaN
df['Generation'] = df['Generation'].map({1: 'First'})
df['Generation']
# Out:
# #
# 1      First
# 2      First
# 3      First
# 3      First
# 4      First
#        ...
# 719      NaN
# 719      NaN
# 720      NaN
# 720      NaN
# 721      NaN
# Name: Generation, Length: 800, dtype: object

# %%
# or we can check with value_count method
df['Generation'].value_counts()

# Output
# shows only First - means 166 times First word got repeted
# and for rest it is NaN - so it didnt count it
# Out:
# Generation
# First    166
# Name: count, dtype: int64

# %% [markdown]
# Using map() with a Function

# %%
# Sample Series
s = pd.Series([1, 2, 3, 4, 5])

# Define a function to apply to each element
def square(x):
    return x ** 2

# Apply the function using map()
result = s.map(square)
print(result)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64

# %% [markdown]
# ### applymap()
# This method applies a function to a dataframe.
#
# The `applymap()` function in Pandas is used to apply a function to every element of a DataFrame.

# %%
df.applymap(type)
# Out:
# /tmp/ipykernel_11968/3828366062.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(type)
#               Name         Type 1           Type 2          Total  \
# #
# 1    <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 2    <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 3    <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 3    <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 4    <class 'str'>  <class 'str'>  <class 'float'>  <class 'int'>
# ..             ...            ...              ...            ...
# 719  <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 719  <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 720  <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 720  <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
# 721  <class 'str'>  <class 'str'>    <class 'str'>  <class 'int'>
#
#                 HP         Attack        Defense        Sp. Atk  \
# #
# 1    <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 2    <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 3    <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 3    <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 4    <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# ..             ...            ...            ...            ...
# 719  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 719  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 720  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 720  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 721  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
#
#            Sp. Def          Speed       Generation      Legendary
# #
# 1    <class 'int'>  <class 'int'>    <class 'str'>  <class 'str'>
# 2    <class 'int'>  <class 'int'>    <class 'str'>  <class 'str'>
# 3    <class 'int'>  <class 'int'>    <class 'str'>  <class 'str'>
# 3    <class 'int'>  <class 'int'>    <class 'str'>  <class 'str'>
# 4    <class 'int'>  <class 'int'>    <class 'str'>  <class 'str'>
# ..             ...            ...              ...            ...
# 719  <class 'int'>  <class 'int'>  <class 'float'>  <class 'str'>
# 719  <class 'int'>  <class 'int'>  <class 'float'>  <class 'str'>
# 720  <class 'int'>  <class 'int'>  <class 'float'>  <class 'str'>
# 720  <class 'int'>  <class 'int'>  <class 'float'>  <class 'str'>
# 721  <class 'int'>  <class 'int'>  <class 'float'>  <class 'str'>
#
# [800 rows x 12 columns]

# %%
# we can specify our own function as well
def uppercase(var: str) -> str:
    return var.upper()

# %%
# so, to apply above function first we need to make sure that every single value in our
# df must be string.

# conveting values into string
df = df.applymap(str)

# now we can apply our own function
df.applymap(uppercase)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      800 non-null    object
#  3   Total       800 non-null    object
#  4   HP          800 non-null    object
#  5   Attack      800 non-null    object
#  6   Defense     800 non-null    object
#  7   Sp. Atk     800 non-null    object
#  8   Sp. Def     800 non-null    object
#  9   Speed       800 non-null    object
#  10  Generation  800 non-null    object
#  11  Legendary   800 non-null    object
# dtypes: object(12)
# memory usage: 81.2+ KB
# /tmp/ipykernel_11968/885127840.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(str)
# /tmp/ipykernel_11968/885127840.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(uppercase)

# %% [markdown]
# * Now, the new version of Pandas is not using `applymap()`
# * Now, Pandas has moved towards using `DataFrame.map()` instead of `applymap()`

# %%
# Sample DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Define a function to apply to each element
def square(x):
    return x ** 2

# Apply the function to each element using map()
result = df.map(square)
result
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36
